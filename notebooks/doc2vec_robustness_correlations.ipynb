# %% [markdown]
# Explore the global terms counts generated by Jared.
# The aim is to define a suitable cut-off frequency which will decide whether a word belongs to the vocabulary or not.

# %%
import numpy as np
import pylab as plt
import os,sys
import pandas as pd
import glob
from scipy.stats import pearsonr, spearmanr
from scipy.spatial.distance import pdist,cdist
# %matplotlib inline  
# %load_ext autoreload
# %autoreload 2

# %%
## general path
path_data = os.path.abspath('/home/visitors/gerlach/Dropbox (Uzzi Lab)/WoS/wos-text-dynamics-data/d2v-wos')
print(path_data)
# Out:
# /home/visitors/gerlach/Dropbox (Uzzi Lab)/WoS/wos-text-dynamics-data/d2v-wos

# %%
N_pairs = 10**5
N =  22606989
n_seed = 12

# %% [markdown]
# ## dataset1

# %%
path_read = os.path.join(path_data,'100-5-5')
# fname_read = 'model_100-5-5.npy.docvecs.doctag_syn0.npy'
fname_read = 'doc_features_normed.npy' ## these are the normed vectors

x = np.load(os.path.join(path_read,fname_read))
N = len(x)

# %%
np.random.seed(n_seed)
i1,i2=0,0
list_dist_x1 = []
for i in range(N_pairs):
    i1,i2=0,0
    while i1 == i2:
        i1,i2 = np.random.randint(N,size=2)#np.random.choice(N,size=2,replace=False)
    x1,x2 = x[i1],x[i2]
    s = pdist([x1,x2])[0]
    list_dist_x1 += [s]

# %% [markdown]
# ## dataset2

# %%
path_read = os.path.join(path_data,'200-5-5')
fname_read = 'model_200-5-5.docvecs.doctag_syn0_lockf.npy'
x = np.load(os.path.join(path_read,fname_read))
N = len(x)

# %%
x[10]
# Out:
# 1.0

# %%
np.random.seed(n_seed)
i1,i2=0,0
list_dist_x1 = []
for i in range(N_pairs):
    i1,i2=0,0
    while i1 == i2:
        i1,i2 = np.random.randint(N,size=2)#np.random.choice(N,size=2,replace=False)
    x1,x2 = x[i1],x[i2]
    s = pdist([x1,x2])[0]
    list_dist_x1 += [s]

# %%
path_read = os.path.join(path_data,'100-5-5')
# fname_read = 'doc_features_normed_100-5-5.npy.indices_1M'
fname_read = 'doc_features_normed_100-5-5.npy.1M.lv_coords'
x = np.loadtxt(os.path.join(path_read,fname_read))[1:]

# %%
len(x),x[1000,:]
# Out:
# (1000000, array([-16.463091,   4.881921]))

# %%
### which indices are these in the complete corpus?

# %%
len(x)
# Out:
# 22606989

# %%
import pickle
fname_read = 'doc_features_normed_100-5-5.npy.indices_1M'
with open(os.path.join(path_read,fname_read),'rb') as f:
    x=pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# <ipython-input-20-28fc94e7a9e5> in <module>()
#       2 fname_read = 'doc_features_normed_100-5-5.npy.indices_1M'
#       3 with open(os.path.join(path_read,fname_read),'rb') as f:
# ----> 4     x=pickle.load(f)
#
# UnpicklingError: unpickling stack underflow
